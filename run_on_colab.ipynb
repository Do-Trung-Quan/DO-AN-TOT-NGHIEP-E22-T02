# %% [markdown]
# # 🚀 Hướng dẫn Chạy Trích xuất Đặc trưng Ảnh trên Google Colab
#
# Notebook này giúp bạn trích xuất đặc trưng ảnh X-quang cực nhanh bằng GPU trên Google Colab (~30 giây).
#
# ### Chuẩn bị trước khi chạy:
# 1. Tải cả thư mục dự án `DO-AN-TOT-NGHIEP-E22-T02` của bạn lên Google Drive (ví dụ ở thư mục gốc Google Drive).
# 2. Khi mở Notebook này trên Google Colab, nhớ chọn Runtime là **T4 GPU**:
#    - Chọn **Runtime** -> **Change runtime type** -> Chọn **T4 GPU** -> Nhấn **Save**.

# %%
# 1. Kết nối (Mount) với Google Drive của bạn
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2. Di chuyển vào thư mục project trên Drive
import os
# Hãy sửa đường dẫn bên dưới nếu thư mục dự án của bạn trên Google Drive nằm ở thư mục con khác
PROJECT_PATH = "/content/drive/MyDrive/DO-AN-TOT-NGHIEP-E22-T02"

if os.path.exists(PROJECT_PATH):
    os.chdir(PROJECT_PATH)
    print("Đã di chuyển tới thư mục:", os.getcwd())
else:
    print(f"❌ Không tìm thấy thư mục {PROJECT_PATH} trên Drive. Vui lòng kiểm tra lại đường dẫn!")

# %%
# 3. Cài đặt các thư viện cần thiết trên môi trường Colab (Dùng gói hi-ml-multimodal)
# !pip install hi-ml-multimodal pyarrow openpyxl pandas numpy

# %%
# 4. Thực thi script trích xuất (tự động phát hiện và chạy trên GPU)
# !python extract_image_features.py
